# %%
# Dependencies and Setup
import pandas as pd

# File to Load
exact_loc_csv = "lat_and_long.csv"
main_csv = "resources/red_and_white_combined.csv"

# Read lat_long data file and store into Pandas DataFrames
loc_df = pd.read_csv(exact_loc_csv)
df = pd.read_csv(main_csv)

# %%
loc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4717 entries, 0 to 4716
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       4717 non-null   int64
#  1   winery     4717 non-null   object
#  2   country    4717 non-null   object
#  3   latitude   2942 non-null   float64
#  4   longitude  2942 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 184.4+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12430 entries, 0 to 12429
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             12430 non-null  object
#  1   Country          12430 non-null  object
#  2   Region           12430 non-null  object
#  3   Winery           12430 non-null  object
#  4   Rating           12430 non-null  float64
#  5   NumberOfRatings  12430 non-null  int64
#  6   Price            12430 non-null  float64
#  7   Year             12430 non-null  object
#  8   Type             12430 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 874.1+ KB

# %%
mask = df["Rating"] >= 4.0
df2 = df[mask]
df2.head()
# Out:
#                          Name  Country                      Region  \
# 1           Ronco Broilo 2010    Italy  Colli Orientali del Friuli
# 2     Weisser Schiefer s 2017  Austria               Südburgenland
# 6   Goldloch Riesling GG 2016  Germany                        Nahe
# 7          Kieselberg GG 2015  Germany                       Pfalz
# 11         Berg Riesling 2018   France                      Alsace
#
#                      Winery  Rating  NumberOfRatings  Price  Year   Type
# 1   Conte d'Attimis Maniago     4.3               25  44.90  2010  white
# 2      Weinbau Uwe Schiefer     4.2               25  33.25  2017  white
# 6                      Diel     4.1               25  33.90  2016  white
# 7               Von Winning     4.1               25  33.95  2015  white
# 11          Domaine Pfister     4.2               25  15.90  2018  white

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4717 entries, 1 to 12426
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             4717 non-null   object
#  1   Country          4717 non-null   object
#  2   Region           4717 non-null   object
#  3   Winery           4717 non-null   object
#  4   Rating           4717 non-null   float64
#  5   NumberOfRatings  4717 non-null   int64
#  6   Price            4717 non-null   float64
#  7   Year             4717 non-null   object
#  8   Type             4717 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 368.5+ KB

# %%
# delete a single row by index value 0
# df = df.drop(labels=0, axis=0)
# df = df.reset_index()
# df.head()

# %%
# df = df.drop(columns="index")
# df.head()

# %%
df2 = df2.rename(columns={"Name": "name", "Country": "country", "Region": "region", "Winery": "winery", "Rating": "rating", "NumberOfRatings": "number_of_ratings", "Price": "price", "Year": "year", "Type": "type"})
df2.head()
# Out:
#                          name  country                      region  \
# 1           Ronco Broilo 2010    Italy  Colli Orientali del Friuli
# 2     Weisser Schiefer s 2017  Austria               Südburgenland
# 6   Goldloch Riesling GG 2016  Germany                        Nahe
# 7          Kieselberg GG 2015  Germany                       Pfalz
# 11         Berg Riesling 2018   France                      Alsace
#
#                      winery  rating  number_of_ratings  price  year   type
# 1   Conte d'Attimis Maniago     4.3                 25  44.90  2010  white
# 2      Weinbau Uwe Schiefer     4.2                 25  33.25  2017  white
# 6                      Diel     4.1                 25  33.90  2016  white
# 7               Von Winning     4.1                 25  33.95  2015  white
# 11          Domaine Pfister     4.2                 25  15.90  2018  white

# %%
loc_df = loc_df.drop(columns=["name", "country", "winery"])
loc_df.head()
# Out:
#     latitude  longitude
# 0  46.009661  13.341692
# 1  47.234046  16.348452
# 2        NaN        NaN
# 3  49.410623   8.186380
# 4  48.585492   7.508339

# %%
new_df = pd.concat([df2, loc_df], join="outer", axis=0)
new_df
# Out:
#                            name  country                      region  \
# 1             Ronco Broilo 2010    Italy  Colli Orientali del Friuli
# 2       Weisser Schiefer s 2017  Austria               Südburgenland
# 6     Goldloch Riesling GG 2016  Germany                        Nahe
# 7            Kieselberg GG 2015  Germany                       Pfalz
# 11           Berg Riesling 2018   France                      Alsace
# ...                         ...      ...                         ...
# 4712                        NaN      NaN                         NaN
# 4713                        NaN      NaN                         NaN
# 4714                        NaN      NaN                         NaN
# 4715                        NaN      NaN                         NaN
# 4716                        NaN      NaN                         NaN
#
#                        winery  rating  number_of_ratings  price  year   type  \
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9434 entries, 1 to 4716
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               4717 non-null   object
#  1   country            4717 non-null   object
#  2   region             4717 non-null   object
#  3   winery             4717 non-null   object
#  4   rating             4717 non-null   float64
#  5   number_of_ratings  4717 non-null   float64
#  6   price              4717 non-null   float64
#  7   year               4717 non-null   object
#  8   type               4717 non-null   object
#  9   latitude           2942 non-null   float64
#  10  longitude          2942 non-null   float64
# dtypes: float64(5), object(6)
# memory usage: 884.4+ KB

# %%
# File to Load
manual_csv = "four_star_wines.csv"

# Read lat_long data file and store into Pandas DataFrames
final_df = pd.read_csv(manual_csv)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4717 entries, 0 to 4716
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             4717 non-null   object
#  1   Country          4717 non-null   object
#  2   Region           4717 non-null   object
#  3   Winery           4717 non-null   object
#  4   Rating           4717 non-null   float64
#  5   NumberOfRatings  4717 non-null   int64
#  6   Price            4717 non-null   float64
#  7   Year             4717 non-null   object
#  8   Type             4717 non-null   object
#  9   latitude         2942 non-null   float64
#  10  longitude        2942 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 405.5+ KB

# %%
# delete a single row by index value 0
df3 = final_df.dropna()
df3 = df3.reset_index(drop=True)
df3.head()
# Out:
#                       Name     Country                      Region  \
# 0        Ronco Broilo 2010       Italy  Colli Orientali del Friuli
# 1  Weisser Schiefer s 2017     Austria              SÃ¼dburgenland
# 2       Kieselberg GG 2015     Germany                       Pfalz
# 3       Berg Riesling 2018      France                      Alsace
# 4          Pinot Gris 2016  Luxembourg                  Luxembourg
#
#                     Winery  Rating  NumberOfRatings  Price  Year   Type  \
# 0  Conte d'Attimis Maniago     4.3               25  44.90  2010  White
# 1     Weinbau Uwe Schiefer     4.2               25  33.25  2017  White
# 2              Von Winning     4.1               25  33.95  2015  White
# 3          Domaine Pfister     4.2               25  15.90  2018  White
# 4     ChÃ¢teau de Schengen     4.1               25  21.44  2016  White
#
#     latitude  longitude
# 0  46.009661  13.341692
# 1  47.234046  16.348452
# 2  49.410623   8.186380
# 3  48.585492   7.508339
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2942 entries, 0 to 2941
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             2942 non-null   object
#  1   Country          2942 non-null   object
#  2   Region           2942 non-null   object
#  3   Winery           2942 non-null   object
#  4   Rating           2942 non-null   float64
#  5   NumberOfRatings  2942 non-null   int64
#  6   Price            2942 non-null   float64
#  7   Year             2942 non-null   object
#  8   Type             2942 non-null   object
#  9   latitude         2942 non-null   float64
#  10  longitude        2942 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 253.0+ KB

# %%
df3_to_csv = dict(archive_name='4_star_wines_full.csv')  
df3.to_csv('4_star_wines_full.csv', index=False)
